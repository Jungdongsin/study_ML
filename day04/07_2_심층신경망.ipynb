# %% [markdown]
# ### 사전 준비

# %%
# 기본적인 패키지부터 추가
import numpy as np
import pandas as pd
import scipy as super

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 설정/차트 마이너스 깨짐현상 해결 / seaborn 화면설정
from matplotlib import rc
import matplotlib.font_manager as fm

plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %% [markdown]
# #### 패션 MNIST 데이터
#
# 데이터 로드

# %%
from tensorflow import keras
from tensorflow.keras.datasets.fashion_mnist import load_data
from sklearn.model_selection import train_test_split

# %%
(train_input, train_target), (test_input, test_target) = load_data()

# %% [markdown]
# ##### 정규화

# %%
train_scaled = train_input /255.0 #0~1사이 실수값으로 변경
train_scaled = train_scaled.reshape(-1, 28*28) # 784개 1차원 배열로 변경

# %%
train_scaled, test_scaled, train_target, test_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %% [markdown]
# ##### 모델

# %%
model = keras.Sequential()
dense1 = keras.layers.Dense(100, activation="sigmoid", input_shape=(784,))
dense2 = keras.layers.Dense(10, activation="softmax")

model.add(dense1)
model.add(dense2)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 100)               78500
#
#  dense_7 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.Sequential(name='fashionMNIST_model')
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden'))
model.add(keras.layers.Dense(10, activation='softmax', name='output'))

# %% [markdown]
# #### 컴파이 -> 훈련

# %%
model.compile(loss="sparse_categorical_crossentropy", metrics="accuracy")
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3210 - accuracy: 0.8836
# Epoch 2/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3086 - accuracy: 0.8882
# Epoch 3/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2977 - accuracy: 0.8914
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2880 - accuracy: 0.8961
# Epoch 5/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2801 - accuracy: 0.8988

# %% [markdown]
# #### ReLU 활성화함수 / Flattern층(2차원->1차원)

# %%
(train_input, train_target), (test_input, test_target) = load_data()

# %%
train_scaled = train_input / 255.0 # 0~1사이 실수값으로 변경

# %%
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %%
train_scaled.shape
# Out:
# (48000, 28, 28)

# %%
print(train_scaled.shape, train_target.shape)
print(val_scaled.shape, val_target.shape)
# Out:
# (48000, 28, 28) (48000,)
# (12000, 28, 28) (12000,)

# %% [markdown]
# ##### 모델(다시 만들기)

# %%
model = keras.Sequential(name="ReLU_fashionMNIST_Deep_Model")
model.add(keras.layers.Flatten(input_shape=(28,28))) # 2차원 입력값을 1차원으로 변경
model.add(keras.layers.Dense(100, activation="relu", name="hidden"))
model.add(keras.layers.Dense(10, activation="softmax", name="output"))

# %%
model.summary()
# Out:
# Model: "ReLU_fashionMNIST_Deep_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 컴파일 -> 훈련

# %%
model.compile(loss="sparse_categorical_crossentropy", metrics="accuracy")
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5357 - accuracy: 0.8112
# Epoch 2/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3958 - accuracy: 0.8586
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3558 - accuracy: 0.8717
# Epoch 4/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3343 - accuracy: 0.8803
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3194 - accuracy: 0.8852
